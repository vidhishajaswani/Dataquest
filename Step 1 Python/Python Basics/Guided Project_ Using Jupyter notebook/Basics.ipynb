# %%
f=open('births.csv','r')
data=f.read()
data
# Out:
# 'year,month,date_of_month,day_of_week,births\n1994,1,1,6,8096\n1994,1,2,7,7772\n1994,1,3,1,10142\n1994,1,4,2,11248\n1994,1,5,3,11053\n1994,1,6,4,11406\n1994,1,7,5,11251\n1994,1,8,6,8653\n1994,1,9,7,7910\n1994,1,10,1,10498\n1994,1,11,2,11706\n1994,1,12,3,11567\n1994,1,13,4,11212\n1994,1,14,5,11570\n1994,1,15,6,8660\n1994,1,16,7,8123\n1994,1,17,1,10567\n1994,1,18,2,11541\n1994,1,19,3,11257\n1994,1,20,4,11682\n1994,1,21,5,11811\n1994,1,22,6,8833\n1994,1,23,7,8310\n1994,1,24,1,11125\n1994,1,25,2,11981\n1994,1,26,3,11514\n1994,1,27,4,11702\n1994,1,28,5,11666\n1994,1,29,6,8988\n1994,1,30,7,8096\n1994,1,31,1,10765\n1994,2,1,2,11755\n1994,2,2,3,11483\n1994,2,3,4,11523\n1994,2,4,5,11677\n1994,2,5,6,8991\n1994,2,6,7,8309\n1994,2,7,1,10984\n1994,2,8,2,12152\n1994,2,9,3,11515\n1994,2,10,4,11623\n1994,2,11,5,11517\n1994,2,12,6,8945\n1994,2,13,7,8171\n1994,2,14,1,11551\n1994,2,15,2,12164\n1994,2,16,3,12009\n1994,2,17,4,11674\n1994,2,18,5,11887\n1994,2,19,6,8946\n1994,2,20,7,8402\n1994,2,21,1,10617
# ...

# %%
text=data.split('\n')

# %%
print(text)
# Out:
# ['year,month,date_of_month,day_of_week,births', '1994,1,1,6,8096', '1994,1,2,7,7772', '1994,1,3,1,10142', '1994,1,4,2,11248', '1994,1,5,3,11053', '1994,1,6,4,11406', '1994,1,7,5,11251', '1994,1,8,6,8653', '1994,1,9,7,7910', '1994,1,10,1,10498', '1994,1,11,2,11706', '1994,1,12,3,11567', '1994,1,13,4,11212', '1994,1,14,5,11570', '1994,1,15,6,8660', '1994,1,16,7,8123', '1994,1,17,1,10567', '1994,1,18,2,11541', '1994,1,19,3,11257', '1994,1,20,4,11682', '1994,1,21,5,11811', '1994,1,22,6,8833', '1994,1,23,7,8310', '1994,1,24,1,11125', '1994,1,25,2,11981', '1994,1,26,3,11514', '1994,1,27,4,11702', '1994,1,28,5,11666', '1994,1,29,6,8988', '1994,1,30,7,8096', '1994,1,31,1,10765', '1994,2,1,2,11755', '1994,2,2,3,11483', '1994,2,3,4,11523', '1994,2,4,5,11677', '1994,2,5,6,8991', '1994,2,6,7,8309', '1994,2,7,1,10984', '1994,2,8,2,12152', '1994,2,9,3,11515', '1994,2,10,4,11623', '1994,2,11,5,11517', '1994,2,12,6,8945', '1994,2,13,7,8171', '1994,2,14,1,11551', '1994,2,15,2,12164', '1994,2,16,3,120
# ...

# %%
text
# Out:
# ['year,month,date_of_month,day_of_week,births',
#  '1994,1,1,6,8096',
#  '1994,1,2,7,7772',
#  '1994,1,3,1,10142',
#  '1994,1,4,2,11248',
#  '1994,1,5,3,11053',
#  '1994,1,6,4,11406',
#  '1994,1,7,5,11251',
#  '1994,1,8,6,8653',
#  '1994,1,9,7,7910',
#  '1994,1,10,1,10498',
#  '1994,1,11,2,11706',
#  '1994,1,12,3,11567',
#  '1994,1,13,4,11212',
#  '1994,1,14,5,11570',
#  '1994,1,15,6,8660',
#  '1994,1,16,7,8123',
#  '1994,1,17,1,10567',
#  '1994,1,18,2,11541',
#  '1994,1,19,3,11257',
#  '1994,1,20,4,11682',
#  '1994,1,21,5,11811',
#  '1994,1,22,6,8833',
#  '1994,1,23,7,8310',
#  '1994,1,24,1,11125',
#  '1994,1,25,2,11981',
#  '1994,1,26,3,11514',
#  '1994,1,27,4,11702',
#  '1994,1,28,5,11666',
#  '1994,1,29,6,8988',
#  '1994,1,30,7,8096',
#  '1994,1,31,1,10765',
#  '1994,2,1,2,11755',
#  '1994,2,2,3,11483',
#  '1994,2,3,4,11523',
#  '1994,2,4,5,11677',
#  '1994,2,5,6,8991',
#  '1994,2,6,7,8309',
#  '1994,2,7,1,10984',
#  '1994,2,8,2,12152',
#  '1994,2,9,3,11515',
# ...

# %%
for each in text:
    myline=each.split(',')
    print(myline)
# Out:
# ['year', 'month', 'date_of_month', 'day_of_week', 'births']
# ['1994', '1', '1', '6', '8096']
# ['1994', '1', '2', '7', '7772']
# ['1994', '1', '3', '1', '10142']
# ['1994', '1', '4', '2', '11248']
# ['1994', '1', '5', '3', '11053']
# ['1994', '1', '6', '4', '11406']
# ['1994', '1', '7', '5', '11251']
# ['1994', '1', '8', '6', '8653']
# ['1994', '1', '9', '7', '7910']
# ['1994', '1', '10', '1', '10498']
# ['1994', '1', '11', '2', '11706']
# ['1994', '1', '12', '3', '11567']
# ['1994', '1', '13', '4', '11212']
# ['1994', '1', '14', '5', '11570']
# ['1994', '1', '15', '6', '8660']
# ['1994', '1', '16', '7', '8123']
# ['1994', '1', '17', '1', '10567']
# ['1994', '1', '18', '2', '11541']
# ['1994', '1', '19', '3', '11257']
# ['1994', '1', '20', '4', '11682']
# ['1994', '1', '21', '5', '11811']
# ['1994', '1', '22', '6', '8833']
# ['1994', '1', '23', '7', '8310']
# ['1994', '1', '24', '1', '11125']
# ['1994', '1', '25', '2', '11981']
# ['1994', '1', '26', '3', '11514']
# ...

# %%
data
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-1-6137cde4893c> in <module>()
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
days={}
new=text[1:len(text)]
print(new)
# Out:
# ['1994,1,1,6,8096', '1994,1,2,7,7772', '1994,1,3,1,10142', '1994,1,4,2,11248', '1994,1,5,3,11053', '1994,1,6,4,11406', '1994,1,7,5,11251', '1994,1,8,6,8653', '1994,1,9,7,7910', '1994,1,10,1,10498', '1994,1,11,2,11706', '1994,1,12,3,11567', '1994,1,13,4,11212', '1994,1,14,5,11570', '1994,1,15,6,8660', '1994,1,16,7,8123', '1994,1,17,1,10567', '1994,1,18,2,11541', '1994,1,19,3,11257', '1994,1,20,4,11682', '1994,1,21,5,11811', '1994,1,22,6,8833', '1994,1,23,7,8310', '1994,1,24,1,11125', '1994,1,25,2,11981', '1994,1,26,3,11514', '1994,1,27,4,11702', '1994,1,28,5,11666', '1994,1,29,6,8988', '1994,1,30,7,8096', '1994,1,31,1,10765', '1994,2,1,2,11755', '1994,2,2,3,11483', '1994,2,3,4,11523', '1994,2,4,5,11677', '1994,2,5,6,8991', '1994,2,6,7,8309', '1994,2,7,1,10984', '1994,2,8,2,12152', '1994,2,9,3,11515', '1994,2,10,4,11623', '1994,2,11,5,11517', '1994,2,12,6,8945', '1994,2,13,7,8171', '1994,2,14,1,11551', '1994,2,15,2,12164', '1994,2,16,3,12009', '1994,2,17,4,11674', '1994,2,18,5,11887', 
# ...

# %%
mydict={}
for each in new:
    x=each.split(',')
    day_of_week=x[3]
    births=x[4]
    if day_of_week in mydict:
        mydict[day_of_week]=mydict[day_of_week]+int(births)
    else:
        mydict[day_of_week]=int(births)
print(mydict)
# Out:
# {'3': 6322855, '7': 4079723, '4': 6288429, '2': 6446196, '1': 5789166, '6': 4562111, '5': 6233657}

# %% [markdown]
# #hola
# ##holaa

# %% [markdown]
# # hello
# ## hello
